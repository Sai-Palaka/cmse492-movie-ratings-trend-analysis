# %%
# load dataset using pandas and explore it
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.DataFrame({
    "year": [2000, 2005, 2010, 2015, 2020],
    "rating": [6.5, 7.0, 7.5, 7.2, 7.8]
})

# Display first few rows
print("First few rows of the dataset:")
print(df.head())

# Display dataset information
print("\nDataset information:")
print(df.info())

# Display summary statistics
print("\nSummary statistics:")
print(df.describe())

# Calculate average rating by year
avg_ratings = df.groupby('year')['rating'].mean()

# Create a line graph
plt.figure(figsize=(10, 6))
plt.plot(avg_ratings.index, avg_ratings.values, marker='o', linewidth=2)
plt.xlabel('Year')
plt.ylabel('Average Rating')
plt.title('Average Movie Ratings Over Time')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# First few rows of the dataset:
#    year  rating
# 0  2000     6.5
# 1  2005     7.0
# 2  2010     7.5
# 3  2015     7.2
# 4  2020     7.8
#
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    5 non-null      int64
#  1   rating  5 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 212.0 bytes
# None
#
# Summary statistics:
#               year    rating
# count     5.000000  5.000000
# mean   2010.000000  7.200000
# std       7.905694  0.494975
# min    2000.000000  6.500000
# 25%    2005.000000  7.000000
# 50%    2010.000000  7.200000
# 75%    2015.000000  7.500000
# max    2020.000000  7.800000
